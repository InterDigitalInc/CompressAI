# %%
# %load_ext autoreload
# %autoreload 2

from matplotlib import pyplot as plt
from torchvision import transforms
import random
import math
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from torchvision import transforms

# %%
from lvc.datasets.rawvideo import RawVideoFolderTupletRGBDataset

dataset = RawVideoFolderTupletRGBDataset({'train': "/data/lvc/clic2021/video/orig-video-yuv/",}, split='train',  patch_size=(384, 384),
                                        intervals=[3])

# %%
for i in range(N):
    idx = random.randint(0, len(dataset))
    sample = dataset[idx]

# %%
N = 5
s = 5
fig, axes = plt.subplots(N, 3, figsize=(s*3, s*N))
for i in range(N):
    idx = random.randint(0, len(dataset))
    sample = dataset[idx]
    for c, (ax, tensor) in enumerate(zip(axes[i], sample)):
        ax.imshow(transforms.ToPILImage()(tensor.clamp(0, 1)))
        ax.set_title(idx)
        ax.axis('off')

# %%
from PIL import Image

img = Image.open('/data/lvc/kodak/train/kodim02.png')
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.RandomAffine(5, translate=(0.05, 0.05), scale=(0.90, 1.10), shear=10),
    transforms.ToPILImage()
])
transform(img)
# Out:
# <PIL.Image.Image image mode=RGB size=768x512 at 0x7FAC4E1FCD30>
